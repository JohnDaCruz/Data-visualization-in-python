# %%
import yfinance as yf
import plotly as ply
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
print(ply.__version__, pd.__version__, sns.__version__, yf.__version__)
# Out:
# 5.12.0 1.5.2 0.12.2 0.2.4

# %%
df = yf.download('PETR4.SA', start='2021-11-01', end='2023-01-04', group_by="ticker")
display(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
# Date
# 2021-11-01 00:00:00-03:00  27.709999  28.320000  27.370001  28.000000
# 2021-11-03 00:00:00-03:00  27.709999  27.850000  26.799999  26.850000
# 2021-11-04 00:00:00-03:00  27.020000  27.240000  25.850000  26.000000
# 2021-11-05 00:00:00-03:00  26.290001  26.540001  25.780001  25.850000
# 2021-11-08 00:00:00-03:00  25.809999  26.660000  25.719999  26.120001
#
#                            Adj Close     Volume
# Date
# 2021-11-01 00:00:00-03:00  14.566390  102157200
# 2021-11-03 00:00:00-03:00  13.968128   83475800
# 2021-11-04 00:00:00-03:00  13.525934   92603400
# 2021-11-05 00:00:00-03:00  13.447899   86264000
# 2021-11-08 00:00:00-03:00  13.588361   59704100

# %%
sns.set_theme(style='darkgrid')
sns.displot(data = df['Close'].dropna(),kde=True)

# %%
y = df['Close']
plt.figure(figsize=(20,7))
plt.plot(y)
plt.title('Fechamento de PETR4 2021-11-01 - 2023-01-04 ')
plt.ylabel('Fechamento R$')
plt.xlabel('Data')
plt.show()
